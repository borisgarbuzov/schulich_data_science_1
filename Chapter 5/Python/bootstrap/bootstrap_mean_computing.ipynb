# %% [markdown]
# # In this section, we will try to estimate the population mean with the help of bootstrap sampling. Let’s import the required libraries:

# %% [markdown]
# Бутстрап - это широко применяемый и чрезвычайно мощный статистический инструмент, который можно использовать для количественной оценки неопределенности, связанной с данным или методом статистического обучения.

# %%
import numpy as np
import seaborn as sns
import random

# %%
# normal distribution 
x = np.random.normal(loc= 500.0, scale=1.0, size=10000)
np.mean(x)
# Out:
# 499.98932369709433

# %% [markdown]
# Now, we will draw 40 samples of size 5 from the distribution (population) and compute the mean for every sample:

# %%
sample_mean = []

# Bootstrap Sampling
for i in range(40):
  y = random.sample(x.tolist(), 5)
  avg = np.mean(y)
  print(np.sort(y))
  sample_mean.append(avg)
# Out:
# [499.53526525 499.77136192 500.04797563 500.21538715 501.79944973]
# [499.85657738 499.91730055 500.37250353 500.37398871 500.77390004]
# [498.9431652  499.32970266 499.70673144 499.9534267  501.26271751]
# [496.97424437 499.78363709 499.94487193 500.54892331 500.86002721]
# [499.65877463 499.68225172 499.95365883 500.2047965  500.73815527]
# [497.95564755 499.58997074 500.81898995 501.00438214 501.46746328]
# [498.52133745 499.29854358 499.78477528 500.51819581 502.39447981]
# [499.08929163 499.37168889 499.61990362 499.81518737 500.97890638]
# [499.5789617  499.61433027 500.53052024 501.13269067 501.66400683]
# [498.70908071 498.7441622  500.00609069 500.17614625 501.03934317]
# [498.82162318 499.35260023 499.47400116 500.11658533 500.26423567]
# [498.98486849 499.91732573 500.39510369 500.53252649 500.61239528]
# [498.44260071 499.56248701 499.85661302 500.72422424 501.72199335]
# [499.32245217 499.52084347 499.68346675 500.01494729 500.73234247]
# [498.72170887 499.47161412 501.15125598 502.07684879 502.28902247]
# [498.98633452 499.26982734 500.48986455 500.50760423 501.22549311]
# [497.986062   498.68073939 499.15300748 499.88457486 500.45632791]
# [499.00529253 499.86376118 500.26937987 501.41537924 501.48835385]
# [497.33476064 498.69385378 499.8781872  500.28060684 500.33523432]
# [500.03886251 500.09805851 500.30236875 501.06579886 501.1295219 ]
# [498.20043919 499.58061269 499.97091903 501.38748504 502.29374191]
# [498.80697762 499.42736807 499.74561777 501.27845756 501.61361551]
# [497.64324068 499.54648387 499.84154741 499.86376118 501.00202601]
# [499.24307168 499.94236886 500.17493972 501.31909    501.37686918]
# [498.97068667 499.20820111 500.06055188 500.61940887 501.17010079]
# [498.7147559  498.76844988 499.91038047 500.22592576 500.97194353]
# [499.0242972  499.57947599 500.25041842 500.26214699 502.42225766]
# [499.77000226 500.04511927 500.35561917 500.93972338 501.55410583]
# [498.44950778 500.99892256 501.214396   501.34572205 501.47869496]
# [498.92989956 499.19735    500.40646952 500.45268844 501.2512372 ]
# [498.45489169 499.22395951 499.94496935 500.20363979 501.49455438]
# [498.41998663 498.87471475 498.98683684 499.31243396 501.22805793]
# [499.48473147 500.64839336 500.66800709 500.92382168 501.03592085]
# [498.31980544 498.94537229 499.18361798 500.07322375 502.15857155]
# [499.38828874 500.00865678 500.34604398 500.36321535 501.09656667]
# [500.08410681 500.25396355 500.38082891 500.5346136  500.61450643]
# [499.51326657 499.92086006 500.23026043 501.1573877  501.6067462 ]
# [498.91241638 499.15600418 499.39100672 500.02737095 500.81973037]
# [498.59295879 499.57301093 499.64879471 500.0905243  500.47262126]
# [498.97287189 499.2772777  500.92624188 501.00486769 502.06044548]

# %% [markdown]
# Let’s check the average of the mean values of all the 40 samples:

# %%
np.mean(sample_mean)
# Out:
# 499.92471756128816

# %% [markdown]
# It turns out to be pretty close to the population mean! This is why Bootstrap Sampling is such a useful technique in statistics and machine learning.
