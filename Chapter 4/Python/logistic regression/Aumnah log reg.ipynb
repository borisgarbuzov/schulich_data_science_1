# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
X = np.array([[100, 500], 
              [10, 400],
              [500, 10000],
              [400, 8000],
              [990, 1000],
              [990,1000]])
y = np.array([0, 0, 0, 1, 1, 1])
import statsmodels.api as sm
import statsmodels.formula.api as smf
#model = LogisticRegression(solver='liblinear', random_state=0)
model = LogisticRegression(random_state=0)
model.fit(X, y)
import matplotlib.pyplot as plt
plt.scatter(*zip(*X), c=y)

# %%
model.coef_, model.intercept_
# Out:
# (array([[ 0.00892364, -0.00013588]]), array([-3.06983215]))

# %%
import statsmodels.api as sm
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=50, n_features=2, cluster_std=5.0,
                  centers=[(0,0), (2,2)], shuffle=False, random_state=12)

logit_model = sm.Logit(y, sm.add_constant(X)).fit()
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.620237
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   50
# Model:                          Logit   Df Residuals:                       47
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 20 Jun 2021   Pseudo R-squ.:                  0.1052
# Time:                        14:23:31   Log-Likelihood:                -31.012
# converged:                       True   LL-Null:                       -34.657
# Covariance Type:            nonrobust   LLR p-value:                   0.02611
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0813      0.308     -0.264      0.792      -0.684       0.522
# x1             0.1230      0.065      1.888      0.059      -0.005       0.251
# x2             0.1104      0.060      1.827      0.068      -0.008       0.229
# ==============================================================================

# %%
from sklearn.preprocessing import StandardScaler
Xs = StandardScaler().fit_transform(X)
print(Xs)
# Out:
# [[ 0.40469241 -0.68185032]
#  [ 0.18696634 -1.61058645]
#  [ 0.66927038 -1.45932382]
#  [-0.03714957 -0.17051896]
#  [-0.80409861  2.55566137]
#  [-0.6065706   0.36950105]
#  [ 0.99302044 -1.16816602]
#  [ 1.22571882 -0.17227028]
#  [ 0.91421978 -0.89363919]
#  [-1.01427143  1.04132214]
#  [ 0.43197255  0.06553416]
#  [ 0.56313801  0.41950059]
#  [-1.13215988 -2.07763597]
#  [-1.6302286  -1.69018257]
#  [-2.13715776 -0.65087596]
#  [-0.54101225 -0.09669959]
#  [ 0.16102999 -0.41117998]
#  [-0.28177647  0.0057686 ]
#  [-0.98374267 -0.71139904]
#  [-0.00854463 -0.67867908]
#  [-0.58207133 -0.15743008]
#  [ 1.21955663  0.22937493]
#  [-0.36081373 -0.59423708]
#  [-0.15052099  1.98164033]
#  [-3.01438591  0.42661044]
#  [ 0.55532725  1.09400028]
#  [-0.74859749  2.22995067]
#  [ 1.28104733  0.25663605]
#  [ 0.48666738 -0.34913555]
#  [ 0.38347853  0.17288166]
#  [ 1.22687005  0.62934717]
#  [ 0.25695644  0.92106016]
#  [ 0.86090405  0.50641152]
#  [-1.10819617  1.24124015]
#  [-0.76564003 -0.6163718 ]
#  [ 0.23635096  0.77000741]
#  [ 1.66521175 -1.23424891]
#  [ 1.72518651  1.79453282]
#  [-0.09997241  0.12001276]
#  [-0.20425385 -0.24620886]
#  [-0.92914302 -1.23603164]
#  [ 0.14752208  0.5383499 ]
#  [ 2.06288848 -0.60857232]
#  [-1.63961086  0.43701915]
#  [-0.10465297  0.62805223]
#  [-0.03998917 -0.84384925]
#  [-0.31480621  1.03479289]
#  [ 0.59300905 -0.57957518]
#  [ 1.15924473 -1.01435669]
#  [-0.17088332  0.48381616]]

# %%
model_s = smf.logit(formula="Y ~ X1s + X2s", data=dfs).fit()
model_s.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-74a73ccc3ac5> in <module>()
# ----> 1 model_s = smf.logit(formula="Y ~ X1s + X2s", data=dfs).fit()
#       2 model_s.summary()
#
# NameError: name 'dfs' is not defined

# %%
dfs = pd.DataFrame({"X1s": Xs[:, 0], "X2s": Xs[:, 1], "Y": y})
dfs
