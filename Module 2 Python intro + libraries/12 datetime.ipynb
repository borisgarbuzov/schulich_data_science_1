# %%
import time
simpletime = time.time()
timetuple = time.localtime(simpletime)
print ("simpletime =", simpletime)
print ("localtime =", timetuple)
print ("type(simpletime) =", type(simpletime))
print ("type(timetuple) =", type(timetuple))
# Out:
# simpletime = 1598151657.2522175
# localtime = time.struct_time(tm_year=2020, tm_mon=8, tm_mday=23, tm_hour=3, tm_min=0, tm_sec=57, tm_wday=6, tm_yday=236, tm_isdst=0)
# type(simpletime) = <class 'float'>
# type(timetuple) = <class 'time.struct_time'>

# %%
import time
timestring = time.asctime( time.localtime(time.time()) )
print ("timestring =", timestring)
print ("type(timestring) =", type(timestring))
# Out:
# timestring = Sun Aug 23 03:01:18 2020
# type(timestring) = <class 'str'>

# %%
# From the datasets, we usually read strings. 
# Then we need to convert them to a date and time format. 
# Example 
from datetime import datetime 
datetime_str = '09/19/18 13:55:26' 
datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S') 
print(type(datetime_object)) 
print(datetime_object) # printed in default format
# Out:
# <class 'datetime.datetime'>
# 2018-09-19 13:55:26
