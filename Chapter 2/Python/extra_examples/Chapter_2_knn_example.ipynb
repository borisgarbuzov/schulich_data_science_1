# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
myURL = "https://raw.githubusercontent.com/borisgarbuzov/schulich_data_science_1/master/Data/heart2.csv"
df = pd.read_csv(myURL)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
"""
Checking whether there is missing data or not, 
if not then it can proceed to the Exploratory Data Analysis (EDA) stage.
"""
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Conducting Exploratory Data Analysis (EDA) to understand our data better
sns.countplot(df['target'])

# %% [markdown]
#     Looks like the target feature is balanced because the number of values 0 and 1 does not differ much.
#     Value 0 for Heart Disease.
#     Value 1 for No Heart Disease.

# %%
f = plt.figure(figsize=(20,4))

f.add_subplot(1,2,1)
sns.distplot(df['age'])

f.add_subplot(1,2,2)
sns.boxplot(df['age'])

# %% [markdown]
#     From the distplot, it can be seen that the density of the data lies in the range of 50–60 years and very rarely patients aged 30 years or below or 80 years and above.
#     The boxplot shows that the data has no outliers.

# %%
f = plt.figure(figsize=(20,4))

f.add_subplot(1,3,1)
sns.countplot(df['sex'], color='red')

f.add_subplot(1,3,2)
sns.countplot(df['cp'], color='green')

f.add_subplot(1,3,3)
sns.countplot(df['fbs'], color='yellow')

# %%
"""
    Male patients turns out to have more numbers or even 2 times the number of female patients.
    Most patients have type CP 0, which is typical angine and the least type is 3, which is asymptomatic.
    The plot above shows that there are many fasting blood sugar values below 120 or 0.
"""
f = plt.figure(figsize=(20,4))

f.add_subplot(1,2,1)
sns.distplot(df['trestbps'])

f.add_subplot(1,2,2)
sns.boxplot(df['trestbps'])

# %%
"""
    For the value of resting blood pressure or trestbps, the most numbers are ranged from 120 to 140 mmHg.
    The trestbps feature has several outliers.
"""

f = plt.figure(figsize=(20,4))

f.add_subplot(1,2,1)
sns.distplot(df['chol'])

f.add_subplot(1,2,2)
sns.boxplot(df['chol'])

# %%
df.corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col3 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col4 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col5 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col6 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col8 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col9 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col10 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col11 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col12 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row0_col13 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col2 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col5 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col6 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col8 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col9 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col10 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col11 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col12 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row1_col13 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col3 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col5 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col6 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col7 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col9 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col10 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col11 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col12 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row2_col13 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col0 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col2 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col5 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col6 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col8 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col9 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col10 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col11 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col12 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row3_col13 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row4_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row4_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row4_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_8ea7be2c_f9e4_11ea_896a_0242ac1c0002row4_col3 {
#             background-color:  #d4d4e8;
#             colo

# %%
#Create KNN Object.
knn = KNeighborsClassifier()

#Create x and y variables.
x = df.drop(columns=['target'])
y = df['target']

#Split data into training and testing.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

#Training the model.
knn.fit(x_train, y_train)

#Predict test data set.
y_pred = knn.predict(x_test)

#Checking performance our model with classification report.
print(classification_report(y_test, y_pred))

#Checking performance our model with ROC Score.
print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50        25
#            1       0.65      0.61      0.63        36
#
#     accuracy                           0.57        61
#    macro avg       0.56      0.57      0.56        61
# weighted avg       0.58      0.57      0.58        61
#
# 0.5655555555555556

# %% [markdown]
#     From the classification report, it can be seen that the model has an average performance of around 57% ranging from precision, recall, f1-score, and support. Accuracy also shows in value of 57%.
#     Then for the AUC score, it can be seen that the value is around 56.5%.

# %%
"""
Because the performance is still low, 
Let's try to use Hyperparameter Tuning to Improve Model Performance.
"""

#List Hyperparameters that we want to tune.
leaf_size = list(range(1,50))
n_neighbors = list(range(1,30))
p=[1,2]

#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)

#Create new KNN object
knn_2 = KNeighborsClassifier()

#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)

#Fit the model

best_model = clf.fit(x,y)

# %%
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])

# %% [markdown]
#     From GridSearch, it can be seen that the best number of leaf_size is 5 while the optimal distance method is Manhattan or p = 1.
#     Then the most optimal number of K is 7.
#     Using Hyperparameters Tuning can improve model performance by about 20% to a range of 77% for all evaluation matrices.
#     The ROC value also increased to 76%.

# %%
y_pred = best_model.predict(x_test)

# %%
print(classification_report(y_test, y_pred))

# %%
roc_auc_score(y_test, y_pred)
